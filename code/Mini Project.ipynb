# %%
import matplotlib.pyplot as myplot
import pandas as pd
import numpy as np

# %%
# Importing the dataset
myData = pd.read_excel('F1.xlsx')
myData
# Out:
#        ax  ay  az  y
# 0       5  39  34  1
# 1       2  41  34  1
# 2       5  39  34  1
# 3      12  38  34  1
# 4       9  38  30  1
# 5      10  36  29  1
# 6      10  36  30  1
# 7      12  36  30  1
# 8      16  36  29  1
# 9      16  37  30  1
# 10     16  36  30  1
# 11     17  37  30  1
# 12     18  37  30  1
# 13     16  37  31  1
# 14     16  36  31  1
# 15     15  39  31  1
# 16     14  39  32  1
# 17     14  40  32  1
# 18     14  39  33  1
# 19     11  40  32  1
# 20     10  39  33  1
# 21      6  40  33  1
# 22      3  38  32  1
# 23      0  39  31  1
# 24      0  41  30  1
# 25      4  36  31  1
# 26     14  37  32  1
# 27     15  36  33  1
# 28     11  36  32  1
# 29     13  35  32  1
# ...    ..  ..  .. ..
# 37310  23  50  33  3
# 37311  26  46  34  3
# 37312  29  41  34  3
# 37313  32  40  35  3
# 37314  35  36  39  3
# 37315  38  35  39  3
# 37316  39  33  42  3
# 37317  38  32  47  3
# 37318  39  30  49  3
# 37319  38  30  51  3
# 37320  39  28  53  3
# ...

# %%
x=myData.iloc[:,0:3].values
y=myData.iloc[:,3].values
x
# Out:
# array([[ 5, 39, 34],
#        [ 2, 41, 34],
#        [ 5, 39, 34],
#        ...,
#        [39, 37, 51],
#        [39, 37, 53],
#        [39, 35, 51]], dtype=int64)

# %%
#Splitting the dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.25,random_state=0)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
x_train=x_train.astype('float64')
x_test=x_test.astype('float64')
# Out:
# (28005, 3)
# (28005,)
# (9335, 3)
# (9335,)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# ## Decision Tree

# %%
#Fitting Decision Tree Classification from the Training Set
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion='entropy',splitter='best',random_state=0)
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
#Predicting the Test Set Results
y_pred=classifier.predict(x_test)
#Making the confusion Matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[4180, 1033,   25],
#        [1878, 1950,   13],
#        [ 208,   41,    7]], dtype=int64)

# %%
accuracy = (cm[0][0]+cm[1][1]+cm[2][2])/(cm[0][0]+cm[1][1]+cm[2][2]+cm[0][1]+cm[0][2]+cm[1][0]+cm[1][2]+cm[2][0]+cm[2][1])
accuracy
# Out:
# 0.6574183181574719

# %% [markdown]
# ## KNN

# %%
# Fitting KNN classifier to the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2)
classifier.fit(x_train,y_train)

# %%
#Predicting the Test Set Results
y_pred=classifier.predict(x_test)
#Making the confusion Matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm

# %%
accuracy = (cm[0][0]+cm[1][1]+cm[2][2])/(cm[0][0]+cm[1][1]+cm[2][2]+cm[0][1]+cm[0][2]+cm[1][0]+cm[1][2]+cm[2][0]+cm[2][1])
accuracy

# %% [markdown]
# ## Naive Bayes Classifier

# %%
#Fitting Naive Bayes in the training set
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(x_train,y_train)

# %%
#Predicting the Test Set Results
y_pred=classifier.predict(x_test)
#Making the confusion Matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm

# %%
accuracy = (cm[0][0]+cm[1][1]+cm[2][2])/(cm[0][0]+cm[1][1]+cm[2][2]+cm[0][1]+cm[0][2]+cm[1][0]+cm[1][2]+cm[2][0]+cm[2][1])
accuracy

# %% [markdown]
# ## Random Forest Classifier

# %%
# Fitting Random Forest Classification to the Training set
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)

# %%
#Predicting the Test Set Results
y_pred=classifier.predict(x_test)
#Making the confusion Matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm

# %%
accuracy = (cm[0][0]+cm[1][1]+cm[2][2])/(cm[0][0]+cm[1][1]+cm[2][2]+cm[0][1]+cm[0][2]+cm[1][0]+cm[1][2]+cm[2][0]+cm[2][1])
accuracy

# %% [markdown]
# ## SVM

# %%
# Fitting classifier to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel='linear', random_state=0)
classifier.fit(x_train, y_train)

# %%
#Predicting the Test Set Results
y_pred=classifier.predict(x_test)
#Making the confusion Matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm

# %%
accuracy = (cm[0][0]+cm[1][1]+cm[2][2])/(cm[0][0]+cm[1][1]+cm[2][2]+cm[0][1]+cm[0][2]+cm[1][0]+cm[1][2]+cm[2][0]+cm[2][1])
accuracy

# %% [markdown]
# ## RBF Kernel SVM

# %%
# Fitting classifier to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel='rbf', random_state=0) #gaussian kernel
classifier.fit(x_train, y_train)

# %%
#Predicting the Test Set Results
y_pred=classifier.predict(x_test)
#Making the confusion Matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm

# %%
accuracy = (cm[0][0]+cm[1][1]+cm[2][2])/(cm[0][0]+cm[1][1]+cm[2][2]+cm[0][1]+cm[0][2]+cm[1][0]+cm[1][2]+cm[2][0]+cm[2][1])
accuracy
